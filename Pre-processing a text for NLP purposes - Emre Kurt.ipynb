# %% [markdown]
# ## Pre-processing a text for NLP purposes - Emre Kurt

# %% [markdown]
# **In this notebook, I will be preparing a text for natural language processing. I'm going to be using lyrics from the song 'Aquemini', by the hip hop duo Outkast. 'Aquemini' is a song off the album with the same name. The procedure will include removing unnecessary components (capitalizations, punctuation, and stop words), tokenization of the text, and lemmatization and stemming.**

# %%
lyrics = open('Aquemini.txt', 'r').read()
lyrics
# Out:
# 'Even the Sun goes down, heroes eventually die\nHoroscopes often lie\nAnd sometimes, "Y"\nNothing is for sure, nothing is for certain\nNothing lasts forever, but until they close the curtain\n(Y\'all know)\nIt\'s him and I: Aquemini\n\nNow is the time to get on—like Spike Lee said, "Get on the Bus"\nGo get your work and keep your beeper chirping—it\'s a must\nIs you on that dust or corn starch? Familiar with that smack, man?\nThe music is like that green stuff provided to you by sack-man\nPacman, how in the fuck you think we gon\' do that, man?\nRiding round Old National on eighteens without no gat, man\nI\'m strapped, man, and ready to bust on any nigga like that, man\nMe and my nigga, we roll together like Batman and Robin\nWe prayed together through hard times, swung hard when it was fitting\nBut now, we tapping the brakes from all them corners that we be bending\nIn Volkswagens and Bonnevilles, Chevrolets and Coupe de Villes\nIf you ain\'t got no rims, nigga, don\'t get no wood-grain steering wheel, for real (Real)\nYou can go on and chill out and still build\nLet your paper stack \'stead of going into overkill\nAnd pay your fuckin\' beeper bill, bitch\n\nEven the Sun goes down, heroes eventually die\nHoroscopes often lie\nAnd sometimes, "Y"\nNothing is for sure, nothing is for certain\nAnd nothing lasts forever, but until they close the curtain\nIt\'s him and I: Aquemini\n\nTwice upon a time, there was a boy who died\nLived happily ever after, but that\'s another chapter\nLive from "home of the brave," with dirty dollars\nBeauty parlors, baby ballers, bowling-ball Impalas\nStreet scholars, majoring in culinary arts—\nYou know, how to work bread, cheese, and dough from scratch\nBut, see, the catch is you can get caught\nKnow what you selling, what you bought, so cut that big talk\nLet\'s walk to the bridge—meet me halfway\nNow you may see some children dead off in the pathway\nIt\'s them poor babies walking slowly to the candy lady\nIt\'s looking bad—\nNeed some hope like the words "maybe," "if," or "probably"\nMore than a hobby\nWhen my turntables get wobbly, they don\'t fall\nI\'m sorry, y\'all, I often drift—I\'m talking gift\nSo when it comes, you never look the horse inside its grill\nOf course, you know I feel like the bearer of bad news\nDon\'t want to be it, but it\'s needed, so what have you?\nNow, question: Is every nigga with dreads for the cause?\nIs every nigga with golds for the fall?\nNaww, so don\'t get caught up in appearance\nIt\'s OutKast, "Aquemini": another Black experience\n\nOkay\n\nEven the Sun goes down, heroes eventually die\nHoroscopes often lie\nAnd sometimes, "Y"\nNothing is for sure, nothing is for certain\nNothing lasts forever, but until they close the curtain\nIt\'s him and I: Aquemini\n\n\nThe name is Big Boi, Daddy Fat Sax, the nigga that like them Cadillacs\nI stay down with these streets \'cause these streets is where my folks at\nBetter know that, some say we pro-Black, but we professional\nWe missed a lot of church, so the music is our confessional\nGet off the testicles and the nutsacks, you bust \'round, we bust back\nG—Get back for real niggas that\'s out here tryna spit facts\nYou \'ear that? You can\'t come near that, maybe you need to quit (Quit)\nBecause "Aquemini" is Aquarius and the Gemini running shit\nLike this, yeah, yeah, yeah, yeah\n\nMy mind warps and bends, floats the wind, count to ten\nMeet the twin, André Ben\', welcome to the lion\'s den\nOriginal skin, many men comprehend\nI extend myself, so you go out and tell a friend\nSin all depends on what you believing in\nFaith is what you make it—that\'s the hardest shit since MC Ren\nAlien can blend right on in with your kin\nLook again, \'cause I swear, I spot one every now and then\nIt\'s happening again, wish I could tell you when\n"André, this is André, y\'all are just gon\' have to make amends"\n\nEven the Sun goes down, heroes eventually die\nHoroscopes often lie\nAnd sometimes, "Y"\nNothing is for sure, nothing is ...

# %%
import re
wordCount = len(re.findall(r'\w+', lyrics))
print("There are %i words in the song."%wordCount)
# Out:
# There are 782 words in the song.

# %%
punc = ["!", "?", ".", '"', "(", ")", ",", ":", "'", "-", "—"]
cleanLyrics = ''
for letter in lyrics:
    if letter not in punc:
        cleanLyrics+=letter
  
cleanLyrics = cleanLyrics.replace("\n", "  ")
cleanLyrics
# Out:
# 'Even the Sun goes down heroes eventually die  Horoscopes often lie  And sometimes Y  Nothing is for sure nothing is for certain  Nothing lasts forever but until they close the curtain  Yall know  Its him and I Aquemini    Now is the time to get onlike Spike Lee said Get on the Bus  Go get your work and keep your beeper chirpingits a must  Is you on that dust or corn starch Familiar with that smack man  The music is like that green stuff provided to you by sackman  Pacman how in the fuck you think we gon do that man  Riding round Old National on eighteens without no gat man  Im strapped man and ready to bust on any nigga like that man  Me and my nigga we roll together like Batman and Robin  We prayed together through hard times swung hard when it was fitting  But now we tapping the brakes from all them corners that we be bending  In Volkswagens and Bonnevilles Chevrolets and Coupe de Villes  If you aint got no rims nigga dont get no woodgrain steering wheel for real Real  You can go on and chill out and still build  Let your paper stack stead of going into overkill  And pay your fuckin beeper bill bitch    Even the Sun goes down heroes eventually die  Horoscopes often lie  And sometimes Y  Nothing is for sure nothing is for certain  And nothing lasts forever but until they close the curtain  Its him and I Aquemini    Twice upon a time there was a boy who died  Lived happily ever after but thats another chapter  Live from home of the brave with dirty dollars  Beauty parlors baby ballers bowlingball Impalas  Street scholars majoring in culinary arts  You know how to work bread cheese and dough from scratch  But see the catch is you can get caught  Know what you selling what you bought so cut that big talk  Lets walk to the bridgemeet me halfway  Now you may see some children dead off in the pathway  Its them poor babies walking slowly to the candy lady  Its looking bad  Need some hope like the words maybe if or probably  More than a hobby  When my turntables get wobbly they dont fall  Im sorry yall I often driftIm talking gift  So when it comes you never look the horse inside its grill  Of course you know I feel like the bearer of bad news  Dont want to be it but its needed so what have you  Now question Is every nigga with dreads for the cause  Is every nigga with golds for the fall  Naww so dont get caught up in appearance  Its OutKast Aquemini another Black experience    Okay    Even the Sun goes down heroes eventually die  Horoscopes often lie  And sometimes Y  Nothing is for sure nothing is for certain  Nothing lasts forever but until they close the curtain  Its him and I Aquemini      The name is Big Boi Daddy Fat Sax the nigga that like them Cadillacs  I stay down with these streets cause these streets is where my folks at  Better know that some say we proBlack but we professional  We missed a lot of church so the music is our confessional  Get off the testicles and the nutsacks you bust round we bust back  GGet back for real niggas thats out here tryna spit facts  You ear that You cant come near that maybe you need to quit Quit  Because Aquemini is Aquarius and the Gemini running shit  Like this yeah yeah yeah yeah    My mind warps and bends floats the wind count to ten  Meet the twin André Ben welcome to the lions den  Original skin many men comprehend  I extend myself so you go out and tell a friend  Sin all depends on what you believing in  Faith is what you make itthats the hardest shit since MC Ren  Alien can blend right on in with your kin  Look again cause I swear I spot one every now and then  Its happening again wish I could tell you when  André this is André yall are just gon have to make amends    Even the Sun goes down heroes eventually die  Horoscopes often lie  And sometimes Y  Nothing is for sure nothing is for certain  And nothing lasts forever but until they close the curtain  Its him and I Aquemini    Finally Igor Weve done it weve done it  Yes master Yes master  Igor weve done it  Uhoh'

# %% [markdown]
# **I think removing only the most common stop words (i.e. "and", "the") wouldn't hurt. I don't think any meaningful conclusion can be made from analyses including those words. Removing swear words also makes sense, as words like "fuck" are usually not used in their literal sense ("fucking ___"). They are mostly used as filler words.**

# %%
cleanLyrics
commonStop = "and I a about an are as at be by com for from how in is it of on or that the this to was what when where who will with the www it's it won't can't don't".split()
stopwords = commonStop+["fuck", "shit", "bitch", "fucking", "fuckin'", "yeah"]
lyricsNoStops = ""
for words in cleanLyrics.lower().split():
    if words not in stopwords:
        lyricsNoStops+=words
        lyricsNoStops+=" "
lyricsNoStops
# Out:
# 'even sun goes down heroes eventually die horoscopes often lie sometimes y nothing sure nothing certain nothing lasts forever but until they close curtain yall know its him i aquemini now time get onlike spike lee said get bus go get your work keep your beeper chirpingits must you dust corn starch familiar smack man music like green stuff provided you sackman pacman you think we gon do man riding round old national eighteens without no gat man im strapped man ready bust any nigga like man me my nigga we roll together like batman robin we prayed together through hard times swung hard fitting but now we tapping brakes all them corners we bending volkswagens bonnevilles chevrolets coupe de villes if you aint got no rims nigga dont get no woodgrain steering wheel real real you can go chill out still build let your paper stack stead going into overkill pay your fuckin beeper bill even sun goes down heroes eventually die horoscopes often lie sometimes y nothing sure nothing certain nothing lasts forever but until they close curtain its him i aquemini twice upon time there boy died lived happily ever after but thats another chapter live home brave dirty dollars beauty parlors baby ballers bowlingball impalas street scholars majoring culinary arts you know work bread cheese dough scratch but see catch you can get caught know you selling you bought so cut big talk lets walk bridgemeet me halfway now you may see some children dead off pathway its them poor babies walking slowly candy lady its looking bad need some hope like words maybe if probably more than hobby my turntables get wobbly they dont fall im sorry yall i often driftim talking gift so comes you never look horse inside its grill course you know i feel like bearer bad news dont want but its needed so have you now question every nigga dreads cause every nigga golds fall naww so dont get caught up appearance its outkast aquemini another black experience okay even sun goes down heroes eventually die horoscopes often lie sometimes y nothing sure nothing certain nothing lasts forever but until they close curtain its him i aquemini name big boi daddy fat sax nigga like them cadillacs i stay down these streets cause these streets my folks better know some say we problack but we professional we missed lot church so music our confessional get off testicles nutsacks you bust round we bust back gget back real niggas thats out here tryna spit facts you ear you cant come near maybe you need quit quit because aquemini aquarius gemini running like my mind warps bends floats wind count ten meet twin andré ben welcome lions den original skin many men comprehend i extend myself so you go out tell friend sin all depends you believing faith you make itthats hardest since mc ren alien can blend right your kin look again cause i swear i spot one every now then its happening again wish i could tell you andré andré yall just gon have make amends even sun goes down heroes eventually die horoscopes often lie sometimes y nothing sure nothing certain nothing lasts forever but until they close curtain its him i aquemini finally igor weve done weve done yes master yes master igor weve done uhoh '

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')
tokens = word_tokenize(lyricsNoStops)
print("There are %i tokens (words) in the corpus."%len(tokens))
# Out:
# There are 557 tokens (words) in the corpus.
# [nltk_data] Downloading package punkt to /Users/emrekurt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def word_count(list):
    counts = dict()
    for word in list:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    return counts

print("There are %i types (unique words) in the corpus."%len(word_count(tokens)))
# Out:
# There are 313 types (unique words) in the corpus.

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

for token in tokens:
    roots = ps.stem(token)
    print([token, roots])
# Out:
# ['even', 'even']
# ['sun', 'sun']
# ['goes', 'goe']
# ['down', 'down']
# ['heroes', 'hero']
# ['eventually', 'eventu']
# ['die', 'die']
# ['horoscopes', 'horoscop']
# ['often', 'often']
# ['lie', 'lie']
# ['sometimes', 'sometim']
# ['y', 'y']
# ['nothing', 'noth']
# ['sure', 'sure']
# ['nothing', 'noth']
# ['certain', 'certain']
# ['nothing', 'noth']
# ['lasts', 'last']
# ['forever', 'forev']
# ['but', 'but']
# ['until', 'until']
# ['they', 'they']
# ['close', 'close']
# ['curtain', 'curtain']
# ['yall', 'yall']
# ['know', 'know']
# ['its', 'it']
# ['him', 'him']
# ['i', 'i']
# ['aquemini', 'aquemini']
# ['now', 'now']
# ['time', 'time']
# ['get', 'get']
# ['onlike', 'onlik']
# ['spike', 'spike']
# ['lee', 'lee']
# ['said', 'said']
# ['get', 'get']
# ['bus', 'bu']
# ['go', 'go']
# ['get', 'get']
# ['your', 'your']
# ['work', 'work']
# ['keep', 'keep']
# ['your', 'your']
# ['beeper', 'beeper']
# ['chirpingits', 'chirpingit']
# ['must', 'must']
# ['you', 'you']
# ['dust', 'dust']
# ['corn', 'corn']
# ['starch', 'starch']
# ['familiar', 'familiar']
# ['smack', 'smack']
# ['man', 'man']
# ['music', 'music']
# ['like', 'like']
# ['green', 'green']
# ['stuff', 'stuff']
# ['provided', 'provid']
# ['you', 'you']
# ['sackman', 'sackman']
# ['pacman', 'pacman']
# ['you', 'you']
# ['think', 'think']
# ['we', 'we']
# ['gon', 'gon']
# ['do', 'do']
# ['man', 'man']
# ['riding', 'ride']
# ['round', 'round']
# ['old', 'old']
# ['national', 'nation']
# ['eighteens', 'eighteen']
# ['without', 'without']
# ['no', 'no']
# ['gat', 'gat']
# ['man', 'man']
# ['im', 'im']
# ['strapped', 'strap']
# ['man', 'man']
# ['ready', 'readi']
# ['bust', 'bust']
# ['any', 'ani']
# ['nigga', 'nigga']
# ['like', 'like']
# ['man', 'man']
# ['me', 'me']
# ['my', 'my']
# ['nigga', 'nigga']
# ['we', 'we']
# ['roll', 'roll']
# ['together', 'togeth']
# ['like', 'like']
# ['batman', 'batman']
# ['robin', 'robin']
# ['we', 'we']
# ['prayed', 'pray']
# ['together', 'togeth']
# ['through', 'through']
# ['hard', 'hard']
# ['times', 'time']
# ['swung', 'swung']
# ['hard', 'hard']
# ['fitting', 'fit']
# ['but', 'but']
# ['now', 'now']
# ['we', 'we']
# ['tapping', 'tap']
# ['brakes', 'brake']
# ['all', 'all']
# ['them', 'them']
# ['corners', 'corner']
# ['we', 'we']
# ['bending', 'bend']
# ['volkswagens', 'volkswagen']
# ['bonnevilles', 'bonnevil']
# ['chevrolets', 'chevrolet']
# ['coupe', 'coup']
# ['de', 'de']
# ['villes', 'vill']
# ['if', 'if']
# ['you', 'you']
# ['aint', 'aint']
# ['got', 'got']
# ['no', 'no']
# ['rims', 'rim']
# ['nigga', 'nigga']
# ['dont', 'dont']
# ['get', 'get']
# ['no', 'no']
# ['woodgrain', 'woodgrain']
# ['steering', 'steer']
# ['wheel', 'wheel']
# ['real', 'real']
# ['real', 'real']
# ['you', 'you']
# ['can', 'can']
# ['go', 'go']
# ['chill', 'chill']
# ['out', 'out']
# ['still', 'still']
# ['build', 'build']
# ['let', 'let']
# ['your', 'your']
# ['paper', 'paper']
# ['stack', 'stack']
# ['stead', 'stead']
# ['going', 'go']
# ['into', 'into']
# ['overkill', 'overkil']
# ['pay', 'pay']
# ['your', 'your']
# ['fuckin', 'fuckin']
# ['beeper', 'beeper']
# ['bill', 'bill']
# ['even', 'even']
# ['sun', 'sun']
# ['goes', 'goe']
# ['down', 'down']
# ['heroes', 'hero']
# ['eventually', 'eventu']
# ['die', 'die']
# ['horoscopes', 'horoscop']
# ['often', 'often']
# ['lie', 'lie']
# ['sometimes', 'sometim']
# ['y', 'y']
# ['nothing', 'noth']
# ['sure', 'sure']
# ['nothing', 'noth']
# ['certain', 'certain']
# ['nothing', 'noth']
# ['lasts', 'last']
# ['forever', 'forev']
# ['but', 'but']
# ['until', 'until']
# ['they', 'they']
# ['close', 'close']
# ['curtain', 'curtain']
# ['its', 'it']
# ['him', 'him']
# ['i', 'i']
# ['aquemini', 'aquemini']
# ['twice', 'twice']
# ['upon', 'upon']
# ['time', 'time']
# ['there', 'there']
# ['boy', 'boy']
# ['died', 'die']
# ['lived', 'live']
# ['happily', 'happili']
# ['ever', 'ever']
# ['after', 'after']
# ['but', 'but']
# ['thats', 'that']
# ['another', 'anoth']
# ['chapter', 'chapter']
# ['live', 'live']
# ['home', 'home']
# ['brave', 'brave']
# ['dirty', 'dirti']
# ['dollars', 'dollar']
# ['beauty', 'beauti']
# ['parlors', 'parlor']
# ['baby', 'babi']
# ['ballers', 'baller']
# ['bowlingball', 'bowlingbal']
# ['impalas', 'impala']
# ['street', 'street']
# ['scholars', 'scholar']
# ['majoring', 'major']
# ['culinary', 'culinari']
# ['arts', 'art']
# ['you', 'you']
# ['know', 'know']
# ['work', 'work']
# ['bread', 'bread']
# ['cheese', 'chees']
# ['dough', 'dough']
# ['scratch', 'scratch']
# ['but', 'but']
# ['see', 'see']
# ['catch', 'catch']
# ['you', 'you']
# ['can', 'can']
# ['get', 'get']
# ['caught', 'caught']
# ['know', 'know']
# ['you', 'you']
# ['selling', 'sell']
# ['you', 'you']
# ['bought', 'bought']
# ['so', 'so']
# ['cut', 'cut']
# ['big', 'big']
# ['talk', 'talk']
# ['lets', 'let']
# ['walk', 'walk']
# ['bridgemeet', 'bridgemeet']
# ['me', 'me']
# ['halfway', 'halfway']
# ['now', 'now']
# ['you', 'you']
# ['may', 'may']
# ['see', 'see']
# ['some', 'some']
# ['children', 'children']
# ['dead', 'dead']
# ['off', 'off']
# ['pathway', 'pathway']
# ['its', 'it']
# ['them', 'them']
# ['poor', 'poor']
# ['babies', 'babi']
# ['walking', 'walk']
# ['slowly', 'slowli']
# ['candy', 'candi']
# ['lady', 'ladi']
# ['its', 'it']
# ['looking', 'look']
# ['bad', 'bad']
# ['need', 'need']
# ['some', 'some']
# ['hope', 'hope']
# ['like', 'like']
# ['words', 'word']
# ['maybe', 'mayb']
# ['if', 'if']
# ['probably', 'probabl']
# ['more', 'more']
# ['than', 'than']
# ['hobby', 'hobbi']
# ['my', 'my']
# ['turntables', 'turntabl']
# ['get', 'get']
# ['wobbly', 'wobbl']
# ['they', 'they']
# ['dont', 'dont']
# ['fall', 'fall']
# ['im', 'im']
# ['sorry', 'sorri']
# ['yall', 'yall']
# ['i', 'i']
# ['often', 'often']
# ['driftim', 'driftim']
# ['talking', 'talk']
# ['gift', 'gift']
# ['so', 'so']
# ['comes', 'come']
# ['you', 'you']
# ['never', 'never']
# ['look', 'look']
# ['horse', 'hors']
# ['inside', 'insid']
# ['its', 'it']
# ['grill', 'grill']
# ['course', 'cours']
# ['you', 'you']
# ['know', 'know']
# ['i', 'i']
# ['feel', 'feel']
# ['like', 'like']
# ['bearer', 'bearer']
# ['bad', 'bad']
# ['news', 'news']
# ['dont', 'dont']
# ['want', 'want']
# ['but', 'but']
# ['its', 'it']
# ['needed', 'need']
# ['so', 'so']
# ['have', 'have']
# ['you', 'you']
# ['now', 'now']
# ['question', 'question']
# ['every', 'everi']
# ['nigga', 'nigga']
# ['dreads', 'dread']
# ['cause', 'caus']
# ['every', 'everi']
# ['nigga', 'nigga']
# ['golds', 'gold']
# ['fall', 'fall']
# ['naww', 'naww']
# ['so', 'so']
# ['dont', 'dont']
# ['get', 'get']
# ['caught', 'caught']
# ['up', 'up']
# ['appearance', 'appear']
# ['its', 'it']
# ['outkast', 'outkast']
# ['aquemini', 'aquemini']
# ['another', 'anoth']
# ['black', 'black']
# ['experience', 'experi']
# ['okay', 'okay']
# ['even', 'even']
# ['sun', 'sun']
# ['goes', 'goe']
# ['down', 'down']
# ['heroes', 'hero']
# ['eventually', 'eventu']
# ['die', 'die']
# ['horoscopes', 'horoscop']
# ['often', 'often']
# ['lie', 'lie']
# ['sometimes', 'sometim']
# ['y', 'y']
# ['nothing', 'noth']
# ['sure', 'sure']
# ['nothing', 'noth']
# ['certain', 'certain']
# ['nothing', 'noth']
# ['lasts', 'last']
# ['forever', 'forev']
# ['but', 'but']
# ['until', 'until']
# ['they', 'they']
# ['close', 'close']
# ['curtain', 'curtain']
# ['its', 'it']
# ['him', 'him']
# ['i', 'i']
# ['aquemini', 'aquemini']
# ['name', 'name']
# ['big', 'big']
# ['boi', 'boi']
# ['daddy', 'daddi']
# ['fat', 'fat']
# ['sax', 'sax']
# ['nigga', 'nigga']
# ['like', 'like']
# ['them', 'them']
# ['cadillacs', 'cadillac']
# ['i', 'i']
# ['stay', 'stay']
# ['down', 'down']
# ['these', 'these']
# ['streets', 'street']
# ['cause', 'caus']
# ['these', 'these']
# ['streets', 'street']
# ['my', 'my']
# ['folks', 'folk']
# ['better', 'better']
# ['know', 'know']
# ['some', 'some']
# ['say', 'say']
# ['we', 'we']
# ['problack', 'problack']
# ['but', 'but']
# ['we', 'we']
# ['professional', 'profession']
# ['we', 'we']
# ['missed', 'miss']
# ['lot', 'lot']
# ['church', 'church']
# ['so', 'so']
# ['music', 'music']
# ['our', 'our']
# ['confessional', 'confession']
# ['get', 'get']
# ['off', 'off']
# ['testicles', 'testicl']
# ['nutsacks', 'nutsack']
# ['you', 'you']
# ['bust', 'bust']
# ['round', 'round']
# ['we', 'we']
# ['bust', 'bust']
# ['back', 'back']
# ['gget', 'gget']
# ['back', 'back']
# ['real', 'real']
# ['niggas', 'nigga']
# ['thats', 'that']
# ['out', 'out']
# ['here', 'here']
# ['tryna', 'tryna']
# ['spit', 'spit']
# ['facts', 'fact']
# ['you', 'you']
# ['ear', 'ear']
# ['you', 'you']
# ['cant', 'cant']
# ['come', 'come']
# ['near', 'near']
# ['maybe', 'mayb']
# ['you', 'you']
# ['need', 'need']
# ['quit', 'quit']
# ['quit', 'quit']
# ['because', 'becaus']
# ['aquemini', 'aquemini']
# ['aquarius', 'aquariu']
# ['gemini', 'gemini']
# ['running', 'run']
# ['like', 'like']
# ['my', 'my']
# ['mind', 'mind']
# ['warps', 'warp']
# ['bends', 'bend']
# ['floats', 'float']
# ['wind', 'wind']
# ['count', 'count']
# ['ten', 'ten']
# ['meet', 'meet']
# ['twin', 'twin']
# ['andré', 'andré']
# ['ben', 'ben']
# ['welcome', 'welcom']
# ['lions', 'lion']
# ['den', 'den']
# ['original', 'origin']
# ['skin', 'skin']
# ['many', 'mani']
# ['men', 'men']
# ['comprehend', 'comprehend']
# ['i', 'i']
# ['extend', 'extend']
# ['myself', 'myself']
# ['so', 'so']
# ['you', 'you']
# ['go', 'go']
# ['out', 'out']
# ['tell', 'tell']
# ['friend', 'friend']
# ['sin', 'sin']
# ['all', 'all']
# ['depends', 'depend']
# ['you', 'you']
# ['believing', 'believ']
# ['faith', 'faith']
# ['you', 'you']
# ['make', 'make']
# ['itthats', 'itthat']
# ['hardest', 'hardest']
# ['since', 'sinc']
# ['mc', 'mc']
# ['ren', 'ren']
# ['alien', 'alien']
# ['can', 'can']
# ['blend', 'blend']
# ['right', 'right']
# ['your', 'your']
# ['kin', 'kin']
# ['look', 'look']
# ['again', 'again']
# ['cause', 'caus']
# ['i', 'i']
# ['swear', 'swear']
# ['i', 'i']
# ['spot', 'spot']
# ['one', 'one']
# ['every', 'everi']
# ['now', 'now']
# ['then', 'then']
# ['its', 'it']
# ['happening', 'happen']
# ['again', 'again']
# ['wish', 'wish']
# ['i', 'i']
# ['could', 'could']
# ['tell', 'tell']
# ['you', 'you']
# ['andré', 'andré']
# ['andré', 'andré']
# ['yall', 'yall']
# ['just', 'just']
# ['gon', 'gon']
# ['have', 'have']
# ['make', 'make']
# ['amends', 'amend']
# ['even', 'even']
# ['sun', 'sun']
# ['goes', 'goe']
# ['down', 'down']
# ['heroes', 'hero']
# ['eventually', 'eventu']
# ['die', 'die']
# ['horoscopes', 'horoscop']
# ['often', 'often']
# ['lie', 'lie']
# ['sometimes', 'sometim']
# ['y', 'y']
# ['nothing', 'noth']
# ['sure', 'sure']
# ['nothing', 'noth']
# ['certain', 'certain']
# ['nothing', 'noth']
# ['lasts', 'last']
# ['forever', 'forev']
# ['but', 'but']
# ['until', 'until']
# ['they', 'they']
# ['close', 'close']
# ['curtain', 'curtain']
# ['its', 'it']
# ['him', 'him']
# ['i', 'i']
# ['aquemini', 'aquemini']
# ['finally', 'final']
# ['igor', 'igor']
# ['weve', 'weve']
# ['done', 'done']
# ['weve', 'weve']
# ['done', 'done']
# ['yes', 'ye']
# ['master', 'master']
# ['yes', 'ye']
# ['master', 'master']
# ['igor', 'igor']
# ['weve', 'weve']
# ['done', 'done']
# ['uhoh', 'uhoh']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
wordnet_lemmatizer = WordNetLemmatizer()

for token in tokens:
    print("Lemma for {} is {}".format(token, wordnet_lemmatizer.lemmatize(token)))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/emrekurt/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemma for even is even
# Lemma for sun is sun
# Lemma for goes is go
# Lemma for down is down
# Lemma for heroes is hero
# Lemma for eventually is eventually
# Lemma for die is die
# Lemma for horoscopes is horoscope
# Lemma for often is often
# Lemma for lie is lie
# Lemma for sometimes is sometimes
# Lemma for y is y
# Lemma for nothing is nothing
# Lemma for sure is sure
# Lemma for nothing is nothing
# Lemma for certain is certain
# Lemma for nothing is nothing
# Lemma for lasts is last
# Lemma for forever is forever
# Lemma for but is but
# Lemma for until is until
# Lemma for they is they
# Lemma for close is close
# Lemma for curtain is curtain
# Lemma for yall is yall
# Lemma for know is know
# Lemma for its is it
# Lemma for him is him
# Lemma for i is i
# Lemma for aquemini is aquemini
# Lemma for now is now
# Lemma for time is time
# Lemma for get is get
# Lemma for onlike is onlike
# Lemma for spike is spike
# Lemma for lee is lee
# Lemma for said is said
# Lemma for get is get
# Lemma for bus is bus
# Lemma for go is go
# Lemma for get is get
# Lemma for your is your
# Lemma for work is work
# Lemma for keep is keep
# Lemma for your is your
# Lemma for beeper is beeper
# Lemma for chirpingits is chirpingits
# Lemma for must is must
# Lemma for you is you
# Lemma for dust is dust
# Lemma for corn is corn
# Lemma for starch is starch
# Lemma for familiar is familiar
# Lemma for smack is smack
# Lemma for man is man
# Lemma for music is music
# Lemma for like is like
# Lemma for green is green
# Lemma for stuff is stuff
# Lemma for provided is provided
# Lemma for you is you
# Lemma for sackman is sackman
# Lemma for pacman is pacman
# Lemma for you is you
# Lemma for think is think
# Lemma for we is we
# Lemma for gon is gon
# Lemma for do is do
# Lemma for man is man
# Lemma for riding is riding
# Lemma for round is round
# Lemma for old is old
# Lemma for national is national
# Lemma for eighteens is eighteen
# Lemma for without is without
# Lemma for no is no
# Lemma for gat is gat
# Lemma for man is man
# Lemma for im is im
# Lemma for strapped is strapped
# Lemma for man is man
# Lemma for ready is ready
# Lemma for bust is bust
# Lemma for any is any
# Lemma for nigga is nigga
# Lemma for like is like
# Lemma for man is man
# Lemma for me is me
# Lemma for my is my
# Lemma for nigga is nigga
# Lemma for we is we
# Lemma for roll is roll
# Lemma for together is together
# Lemma for like is like
# Lemma for batman is batman
# Lemma for robin is robin
# Lemma for we is we
# Lemma for prayed is prayed
# Lemma for together is together
# Lemma for through is through
# Lemma for hard is hard
# Lemma for times is time
# Lemma for swung is swung
# Lemma for hard is hard
# Lemma for fitting is fitting
# Lemma for but is but
# Lemma for now is now
# Lemma for we is we
# Lemma for tapping is tapping
# Lemma for brakes is brake
# Lemma for all is all
# Lemma for them is them
# Lemma for corners is corner
# Lemma for we is we
# Lemma for bending is bending
# Lemma for volkswagens is volkswagens
# Lemma for bonnevilles is bonnevilles
# Lemma for chevrolets is chevrolets
# Lemma for coupe is coupe
# Lemma for de is de
# Lemma for villes is villes
# Lemma for if is if
# Lemma for you is you
# Lemma for aint is aint
# Lemma for got is got
# Lemma for no is no
# Lemma for rims is rim
# Lemma for nigga is nigga
# Lemma for dont is dont
# Lemma for get is get
# Lemma for no is no
# Lemma for woodgrain is woodgrain
# Lemma for steering is steering
# Lemma for wheel is wheel
# Lemma for real is real
# Lemma for real is real
# Lemma for you is you
# Lemma for can is can
# Lemma for go is go
# Lemma for chill is chill
# Lemma for out is out
# Lemma for still is still
# Lemma for build is build
# Lemma for let is let
# Lemma for your is your
# Lemma for paper is paper
# Lemma for stack is stack
# Lemma for stead is stead
# Lemma for going is going
# Lemma for into is into
# Lemma for overkill is overkill
# Lemma for pay is pay
# Lemma for your is your
# Lemma for fuckin is fuckin
# Lemma for beeper is beeper
# Lemma for bill is bill
# Lemma for even is even
# Lemma for sun is sun
# Lemma for goes is go
# Lemma for down is down
# Lemma for heroes is hero
# Lemma for eventually is eventually
# Lemma for die is die
# Lemma for horoscopes is horoscope
# Lemma for often is often
# Lemma for lie is lie
# Lemma for sometimes is sometimes
# Lemma for y is y
# Lemma for nothing is nothing
# Lemma for sure is sure
# Lemma for nothing is nothing
# Lemma for certain is certain
# Lemma for nothing is nothing
# Lemma for lasts is last
# Lemma for forever is forever
# Lemma for but is but
# Lemma for until is until
# Lemma for they is they
# Lemma for close is close
# Lemma for curtain is curtain
# Lemma for its is it
# Lemma for him is him
# Lemma for i is i
# Lemma for aquemini is aquemini
# Lemma for twice is twice
# Lemma for upon is upon
# Lemma for time is time
# Lemma for there is there
# Lemma for boy is boy
# Lemma for died is died
# Lemma for lived is lived
# Lemma for happily is happily
# Lemma for ever is ever
# Lemma for after is after
# Lemma for but is but
# Lemma for thats is thats
# Lemma for another is another
# Lemma for chapter is chapter
# Lemma for live is live
# Lemma for home is home
# Lemma for brave is brave
# Lemma for dirty is dirty
# Lemma for dollars is dollar
# Lemma for beauty is beauty
# Lemma for parlors is parlor
# Lemma for baby is baby
# Lemma for ballers is ballers
# Lemma for bowlingball is bowlingball
# Lemma for impalas is impala
# Lemma for street is street
# Lemma for scholars is scholar
# Lemma for majoring is majoring
# Lemma for culinary is culinary
# Lemma for arts is art
# Lemma for you is you
# Lemma for know is know
# Lemma for work is work
# Lemma for bread is bread
# Lemma for cheese is cheese
# Lemma for dough is dough
# Lemma for scratch is scratch
# Lemma for but is but
# Lemma for see is see
# Lemma for catch is catch
# Lemma for you is you
# Lemma for can is can
# Lemma for get is get
# Lemma for caught is caught
# Lemma for know is know
# Lemma for you is you
# Lemma for selling is selling
# Lemma for you is you
# Lemma for bought is bought
# Lemma for so is so
# Lemma for cut is cut
# Lemma for big is big
# Lemma for talk is talk
# Lemma for lets is let
# Lemma for walk is walk
# Lemma for bridgemeet is bridgemeet
# Lemma for me is me
# Lemma for halfway is halfway
# Lemma for now is now
# Lemma for you is you
# Lemma for may is may
# Lemma for see is see
# Lemma for some is some
# Lemma for children is child
# Lemma for dead is dead
# Lemma for off is off
# Lemma for pathway is pathway
# Lemma for its is it
# Lemma for them is them
# Lemma for poor is poor
# Lemma for babies is baby
# Lemma for walking is walking
# Lemma for slowly is slowly
# Lemma for candy is candy
# Lemma for lady is lady
# Lemma for its is it
# Lemma for looking is looking
# Lemma for bad is bad
# Lemma for need is need
# Lemma for some is some
# Lemma for hope is hope
# Lemma for like is like
# Lemma for words is word
# Lemma for maybe is maybe
# Lemma for if is if
# Lemma for probably is probably
# Lemma for more is more
# Lemma for than is than
# Lemma for hobby is hobby
# Lemma for my is my
# Lemma for turntables is turntable
# Lemma for get is get
# Lemma for wobbly is wobbly
# Lemma for they is they
# Lemma for dont is dont
# Lemma for fall is fall
# Lemma for im is im
# Lemma for sorry is sorry
# Lemma for yall is yall
# Lemma for i is i
# Lemma for often is often
# Lemma for driftim is driftim
# Lemma for talking is talking
# Lemma for gift is gift
# Lemma for so is so
# Lemma for comes is come
# Lemma for you is you
# Lemma for never is never
# Lemma for look is look
# Lemma for horse is horse
# Lemma for inside is inside
# Lemma for its is it
# Lemma for grill is grill
# Lemma for course is course
# Lemma for you is you
# Lemma for know is know
# Lemma for i is i
# Lemma for feel is feel
# Lemma for like is like
# Lemma for bearer is bearer
# Lemma for bad is bad
# Lemma for news is news
# Lemma for dont is dont
# Lemma for want is want
# Lemma for but is but
# Lemma for its is it
# Lemma for needed is needed
# Lemma for so is so
# Lemma for have is have
# Lemma for you is you
# Lemma for now is now
# Lemma for question is question
# Lemma for every is every
# Lemma for nigga is nigga
# Lemma for dreads is dread
# Lemma for cause is cause
# Lemma for every is every
# Lemma for nigga is nigga
# Lemma for golds is gold
# Lemma for fall is fall
# Lemma for naww is naww
# Lemma for so is so
# Lemma for dont is dont
# Lemma for get is get
# Lemma for caught is caught
# Lemma for up is up
# Lemma for appearance is appearance
# Lemma for its is it
# Lemma for outkast is outkast
# Lemma for aquemini is aquemini
# Lemma for another is another
# Lemma for black is black
# Lemma for experience is experience
# Lemma for okay is okay
# Lemma for even is even
# Lemma for sun is sun
# Lemma for goes is go
# Lemma for down is down
# Lemma for heroes is hero
# Lemma for eventually is eventually
# Lemma for die is die
# Lemma for horoscopes is horoscope
# Lemma for often is often
# Lemma for lie is lie
# Lemma for sometimes is sometimes
# Lemma for y is y
# Lemma for nothing is nothing
# Lemma for sure is sure
# Lemma for nothing is nothing
# Lemma for certain is certain
# Lemma for nothing is nothing
# Lemma for lasts is last
# Lemma for forever is forever
# Lemma for but is but
# Lemma for until is until
# Lemma for they is they
# Lemma for close is close
# Lemma for curtain is curtain
# Lemma for its is it
# Lemma for him is him
# Lemma for i is i
# Lemma for aquemini is aquemini
# Lemma for name is name
# Lemma for big is big
# Lemma for boi is boi
# Lemma for daddy is daddy
# Lemma for fat is fat
# Lemma for sax is sax
# Lemma for nigga is nigga
# Lemma for like is like
# Lemma for them is them
# Lemma for cadillacs is cadillacs
# Lemma for i is i
# Lemma for stay is stay
# Lemma for down is down
# Lemma for these is these
# Lemma for streets is street
# Lemma for cause is cause
# Lemma for these is these
# Lemma for streets is street
# Lemma for my is my
# Lemma for folks is folk
# Lemma for better is better
# Lemma for know is know
# Lemma for some is some
# Lemma for say is say
# Lemma for we is we
# Lemma for problack is problack
# Lemma for but is but
# Lemma for we is we
# Lemma for professional is professional
# Lemma for we is we
# Lemma for missed is missed
# Lemma for lot is lot
# Lemma for church is church
# Lemma for so is so
# Lemma for music is music
# Lemma for our is our
# Lemma for confessional is confessional
# Lemma for get is get
# Lemma for off is off
# Lemma for testicles is testicle
# Lemma for nutsacks is nutsacks
# Lemma for you is you
# Lemma for bust is bust
# Lemma for round is round
# Lemma for we is we
# Lemma for bust is bust
# Lemma for back is back
# Lemma for gget is gget
# Lemma for back is back
# Lemma for real is real
# Lemma for niggas is nigga
# Lemma for thats is thats
# Lemma for out is out
# Lemma for here is here
# Lemma for tryna is tryna
# Lemma for spit is spit
# Lemma for facts is fact
# Lemma for you is you
# Lemma for ear is ear
# Lemma for you is you
# Lemma for cant is cant
# Lemma for come is come
# Lemma for near is near
# Lemma for maybe is maybe
# Lemma for you is you
# Lemma for need is need
# Lemma for quit is quit
# Lemma for quit is quit
# Lemma for because is because
# Lemma for aquemini is aquemini
# Lemma for aquarius is aquarius
# Lemma for gemini is gemini
# Lemma for running is running
# Lemma for like is like
# Lemma for my is my
# Lemma for mind is mind
# Lemma for warps is warp
# Lemma for bends is bend
# Lemma for floats is float
# Lemma for wind is wind
# Lemma for count is count
# Lemma for ten is ten
# Lemma for meet is meet
# Lemma for twin is twin
# Lemma for andré is andré
# Lemma for ben is ben
# Lemma for welcome is welcome
# Lemma for lions is lion
# Lemma for den is den
# Lemma for original is original
# Lemma for skin is skin
# Lemma for many is many
# Lemma for men is men
# Lemma for comprehend is comprehend
# Lemma for i is i
# Lemma for extend is extend
# Lemma for myself is myself
# Lemma for so is so
# Lemma for you is you
# Lemma for go is go
# Lemma for out is out
# Lemma for tell is tell
# Lemma for friend is friend
# Lemma for sin is sin
# Lemma for all is all
# Lemma for depends is depends
# Lemma for you is you
# Lemma for believing is believing
# Lemma for faith is faith
# Lemma for you is you
# Lemma for make is make
# Lemma for itthats is itthats
# Lemma for hardest is hardest
# Lemma for since is since
# Lemma for mc is mc
# Lemma for ren is ren
# Lemma for alien is alien
# Lemma for can is can
# Lemma for blend is blend
# Lemma for right is right
# Lemma for your is your
# Lemma for kin is kin
# Lemma for look is look
# Lemma for again is again
# Lemma for cause is cause
# Lemma for i is i
# Lemma for swear is swear
# Lemma for i is i
# Lemma for spot is spot
# Lemma for one is one
# Lemma for every is every
# Lemma for now is now
# Lemma for then is then
# Lemma for its is it
# Lemma for happening is happening
# Lemma for again is again
# Lemma for wish is wish
# Lemma for i is i
# Lemma for could is could
# Lemma for tell is tell
# Lemma for you is you
# Lemma for andré is andré
# Lemma for andré is andré
# Lemma for yall is yall
# Lemma for just is just
# Lemma for gon is gon
# Lemma for have is have
# Lemma for make is make
# Lemma for amends is amends
# Lemma for even is even
# Lemma for sun is sun
# Lemma for goes is go
# Lemma for down is down
# Lemma for heroes is hero
# Lemma for eventually is eventually
# Lemma for die is die
# Lemma for horoscopes is horoscope
# Lemma for often is often
# Lemma for lie is lie
# Lemma for sometimes is sometimes
# Lemma for y is y
# Lemma for nothing is nothing
# Lemma for sure is sure
# Lemma for nothing is nothing
# Lemma for certain is certain
# Lemma for nothing is nothing
# Lemma for lasts is last
# Lemma for forever is forever
# Lemma for but is but
# Lemma for until is until
# Lemma for they is they
# Lemma for close is close
# Lemma for curtain is curtain
# Lemma for its is it
# Lemma for him is him
# Lemma for i is i
# Lemma for aquemini is aquemini
# Lemma for finally is finally
# Lemma for igor is igor
# Lemma for weve is weve
# Lemma for done is done
# Lemma for weve is weve
# Lemma for done is done
# Lemma for yes is yes
# Lemma for master is master
# Lemma for yes is yes
# Lemma for master is master
# Lemma for igor is igor
# Lemma for weve is weve
# Lemma for done is done
# Lemma for uhoh is uhoh

# %% [markdown]
# **At this point, the singular text we used is cleaned and ready for our relevant analytical purposes. If at any point we want to include what we have previously removed, the code can be erased.**
